# %% [markdown]
# <a href="https://colab.research.google.com/github/Brown8893/C/blob/master/python_300_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#我的python練習(Ch4-4.1)
import random 

# Generate random numbers
number1 = random.randint(0, 9)
number2 = random.randint(0, 9)

# Prompt the user to enter an answer
answer = eval(input("What is " + str(number1) + " + " 
    + str(number2) + "? "))
    
# Display result    
print(number1, "+", number2, "=", answer, 
    "is", number1 + number2 == answer)
# Out:
# What is 4 + 1? 5
# TypeErrorTraceback (most recent call last)
# <ipython-input-3-7336d61f6761> in <module>()
#       7 # Prompt the user to enter an answer
#       8 answer = eval(input("What is " + str(number1) + " + "
# ----> 9     + str(number2) + "? "))
#      10
#      11 # Display result
#
# TypeError: eval() arg 1 must be a string or code object

# %% [markdown]
# Chapter 4_practice 4.1
